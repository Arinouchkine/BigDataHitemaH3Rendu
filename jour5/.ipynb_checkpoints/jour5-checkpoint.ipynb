# %%
import pandas as pd 
import numpy as np 
from sklearn import linear_model 
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('./price_availability.csv', sep = ';')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4748696 entries, 0 to 4748695
# Data columns (total 7 columns):
# listing_id        int64
# day               object
# created           object
# available         bool
# local_currency    object
# local_price       int64
# min_nights        int64
# dtypes: bool(1), int64(3), object(3)
# memory usage: 167.6+ MB

# %%
df2 = pd.read_csv('./listings_final.csv', sep = ';')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
# Unnamed: 0                  1000 non-null int64
# listing_id                  1000 non-null int64
# name                        1000 non-null object
# type                        1000 non-null object
# city                        1000 non-null object
# neighborhood                935 non-null object
# latitude                    1000 non-null float64
# longitude                   1000 non-null float64
# person_capacity             1000 non-null int64
# beds                        1000 non-null int64
# bedrooms                    1000 non-null int64
# bathrooms                   1000 non-null float64
# is_rebookable               1000 non-null bool
# is_new_listing              1000 non-null bool
# is_fully_refundable         1000 non-null bool
# is_host_highly_rated        1000 non-null bool
# is_business_travel_ready    1000 non-null bool
# pricing_weekly_factor       1000 non-null float64
# pricing_monthly_factor      1000 non-null float64
# dtypes: bool(5), float64(5), int64(5), object(4)
# memory usage: 98.7+ KB

# %%
dfu = pd.merge(df, df2, on='listing_id')

# %%
dfu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 402616 entries, 0 to 402615
# Data columns (total 25 columns):
# listing_id                  402616 non-null int64
# day                         402616 non-null object
# created                     402616 non-null object
# available                   402616 non-null bool
# local_currency              402616 non-null object
# local_price                 402616 non-null int64
# min_nights                  402616 non-null int64
# Unnamed: 0                  402616 non-null int64
# name                        402616 non-null object
# type                        402616 non-null object
# city                        402616 non-null object
# neighborhood                377260 non-null object
# latitude                    402616 non-null float64
# longitude                   402616 non-null float64
# person_capacity             402616 non-null int64
# beds                        402616 non-null int64
# bedrooms                    402616 non-null int64
# bathrooms                   402616 non-null float64
# is_rebookable               402616 non-null bool
# is_new_listing              402616 non-null bool
# is_fully_refundable         402616 non-null bool
# is_host_highly_rated        402616 non-null bool
# is_business_travel_ready    402616 non-null bool
# pricing_weekly_factor       402616 non-null float64
# pricing_monthly_factor      402616 non-null float64
# dtypes: bool(6), float64(5), int64(7), object(7)
# memory usage: 53.0+ MB

# %%
dfu.head()
# Out:
#    listing_id         day                       created  available  \
# 0    17757345  2018-10-14  2018-09-27 10:40:07.000+0000      False
# 1    17757345  2018-10-14  2018-09-27 06:05:54.000+0000      False
# 2    17757345  2018-10-14  2018-09-26 19:31:41.000+0000      False
# 3    17757345  2018-10-05  2018-09-27 10:40:07.000+0000      False
# 4    17757345  2018-10-05  2018-09-27 06:05:54.000+0000      False
#
#   local_currency  local_price  min_nights  Unnamed: 0  \
# 0            EUR           40           1         540
# 1            EUR           40           1         540
# 2            EUR           40           1         540
# 3            EUR           40           1         540
# 4            EUR           40           1         540
#
#                           name          type  ... beds bedrooms  bathrooms  \
# 0  En plein cœur de Belleville  private_room  ...    1        1        1.0
# 1  En plein cœur de Belleville  private_room  ...    1        1        1.0
# 2  En plein cœur de Belleville  private_room  ...    1        1        1.0
# 3  En plein cœur de Belleville  private_room  ...    1        1        1.0
# 4  En plein cœur de Belleville  private_room  ...    1        1        1.0
#
#    is_rebookable  is_new_listing  is_fully_refundable  is_host_highly_rated  \
# 0          False           False                 True                 False
# 1          False           False                 True                 False
# 2          False           False                 True                 False
# 3          False           False                 True                 False
# 4          False           False                 True                 False
#
#    is_business_travel_ready  pricing_weekly_factor  pricing_monthly_factor
# 0                     False                    1.0                     1.0
# 1                     False                    1.0                     1.0
# 2                     False                    1.0                     1.0
# 3                     False                    1.0                     1.0
# 4                     False                    1.0                     1.0
#
# [5 rows x 25 columns]
