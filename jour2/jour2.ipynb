# %%
import numpy as np
import pandas as pd
import matplotlib as mp 
import seaborn as sb
#Visualisation d’un nuage de points et exploration des variables
df = pd.read_csv('./data/data/house_pricing.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
#tips = sb.load_dataset('./data/data/house_pricing.csv')
sb.relplot("LotArea", "SalePrice", data=df)

# %%
sb.scatterplot("LotArea", "SalePrice", data=df.loc[(df['LotArea'] <  20000 ) & (df['SalePrice'] < 500000)])
dft = df.loc[(df['LotArea'] <=  20000 ) & (df['SalePrice'] >= 50000)]
dft.describe()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1402.000000  1402.000000  1163.000000   1402.000000  1402.000000
# mean    730.026391    57.154066    69.184867   9362.393723     6.096291
# std     422.228348    42.419632    21.401322   3329.506425     1.357034
# min       1.000000    20.000000    21.000000   1300.000000     1.000000
# 25%     363.250000    20.000000    59.000000   7454.750000     5.000000
# 50%     732.500000    50.000000    69.000000   9328.500000     6.000000
# 75%    1095.750000    70.000000    80.000000  11298.250000     7.000000
# max    1460.000000   190.000000   182.000000  19900.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1402.000000  1402.000000   1402.000000  1395.000000  1402.000000  ...
# mean      5.578459  1971.580599   1985.007846   101.354122   429.905849  ...
# std       1.104100    30.210792     20.583128   173.387200   424.544429  ...
# ...

# %%
sb.scatterplot("LotArea", "SalePrice", data=df[(df['LotArea'] <  20000 ) & (df['SalePrice'] < 500000)])
dft = df.loc[(df['LotArea']>  20000 ) & (df['SalePrice'] > 50000)]
dft.describe()
# Out:
#                 Id  MSSubClass  LotFrontage        LotArea  OverallQual  \
# count    53.000000   53.000000    33.000000      53.000000    53.000000
# mean    756.339623   51.886792   103.272727   41362.056604     6.490566
# std     412.974899   40.325913    65.307098   38596.499967     1.648107
# min      54.000000   20.000000    42.000000   20431.000000     4.000000
# 25%     418.000000   20.000000    60.000000   21872.000000     5.000000
# 50%     707.000000   50.000000    90.000000   26142.000000     6.000000
# 75%    1108.000000   60.000000   118.000000   40094.000000     7.000000
# max    1447.000000  190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count    53.000000    53.000000     53.000000    52.000000    53.000000  ...
# mean      5.622642  1966.981132   1984.396226   176.192308   838.509434  ...
# std       1.259219    28.074414     20.662433   323.227901   895.709917  ...
# ...

# %%
sb.relplot("LotArea", "LotFrontage", data=df)

# %%
sb.scatterplot("LotArea", "LotFrontage", data=df[(df['LotFrontage'] <  200 ) & (df['LotArea'] < 100000)])

# %%
#Visualisation de relations continues


df2 = pd.read_csv('./data/data/sales_predictions.csv')

# %%
df2.describe()
# Out:
#        date_block_num       shop_id       item_id    item_price  item_cnt_day
# count    2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06
# mean     1.456991e+01  3.300173e+01  1.019723e+04  8.908532e+02  1.242641e+00
# std      9.422988e+00  1.622697e+01  6.324297e+03  1.729800e+03  2.618834e+00
# min      0.000000e+00  0.000000e+00  0.000000e+00 -1.000000e+00 -2.200000e+01
# 25%      7.000000e+00  2.200000e+01  4.476000e+03  2.490000e+02  1.000000e+00
# 50%      1.400000e+01  3.100000e+01  9.343000e+03  3.990000e+02  1.000000e+00
# 75%      2.300000e+01  4.700000e+01  1.568400e+04  9.990000e+02  1.000000e+00
# max      3.300000e+01  5.900000e+01  2.216900e+04  3.079800e+05  2.169000e+03

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
# date              object
# date_block_num    int64
# shop_id           int64
# item_id           int64
# item_price        float64
# item_cnt_day      float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 123.2+ MB

# %%
sb.relplot("item_price", "item_cnt_day", data=df2)

# %%
sb.relplot("item_price", "date_block_num", data=df2)

# %%
sb.relplot("date", "item_price", data=df2)

# %%
df2s = df2.sample(50)

# %%
sb.relplot("date", "item_price", data=df2s)

# %%
figure1 = sb.relplot("date", "item_price", data=df2s)
figure1.fig.set_figwidth(20)
figure1.fig.set_figheight(6)

# %%
df2s['date'] = pd.to_datetime(df2s['date'])
figure1 = sb.relplot("date", "item_price", data=df2s)
# Out:
# c:\users\arino\appdata\local\programs\python\python38-32\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
#Visualisation de variables catégoriques

df3 = pd.read_csv('./data/data/ibm_hr_attrition.csv')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %%
df3.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df3
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
sb.catplot(x='Attrition',y='JobSatisfaction',hue='EducationField', data=df3,kind='bar')

# %%
sb.boxplot(x='Attrition',y='JobSatisfaction',hue='EducationField', data=df3,)

# %%
sb.boxplot(x='Attrition',y='JobSatisfaction',hue='EducationField', data=df3, showfliers = True)

# %%
#on peut pas voir les valeurs abberante car l echelle de jobsatisfaction et attrition sont trop faible en quantite pour voir les abberation
#la seule conclusion qu on peut observe c'estque les gens qui ont quitter entrprise ont des note de satisfaction beacoup plus basse que ceux qui reste dans entreprise
#de ce fait on peut pas sortire les valeurs aberante

# %%
df3.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
sb.boxplot(x='Attrition',y='TotalWorkingYears',hue='EducationField', data=df3, showfliers = True)

# %%
sb.boxplot(x='Attrition',y='TotalWorkingYears',hue='EducationField', data=df3[df3['TotalWorkingYears']>20], showfliers = True)
#la on observe les abbeation car on a reemarque que les abberation sont souvent present a partire plus de 20 ans

# %%
df3['Attrition'] = df3['Attrition'].replace(to_replace=['Yes','No'],value=[1,0])

# %%
df3
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
sb.catplot(x='Attrition',y='TotalWorkingYears',hue='EducationField', data=df3[df3['TotalWorkingYears']>20],kind='bar')

# %%
#Visualisation d’une distribution 
df4 = pd.read_csv('./data/data/ibm_hr_attrition.csv')

sb.distplot(df4['MonthlyIncome']);

# %%
sb.distplot(df4[df4['MonthlyIncome']<50000]['MonthlyIncome']);

# %%
#Visualisation d’une relation linéaire 

df5 = pd.read_csv('./data/data/ibm_hr_attrition.csv')
df5['Attrition'] = df5['Attrition'].replace(to_replace=['Yes','No'],value=[1,0])
sb.lmplot(x="Age", y="Attrition", data=df5)
#lus age augmente plus ont a des chance de partire de ibm

# %%
sb.lmplot(x="YearsWithCurrManager", y="Attrition", data=df5)
#pareil pour les annes c'est pareil

# %%
#Visualisation d’une heatmap 
df6 = pd.read_csv('./data/data/house_pricing.csv')
df6
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df6m = df6[df6.columns[-15:]]


df6m
# Out:
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# ...          ...          ...            ...        ...          ...
# 1455           0           40              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# ...

# %%
import matplotlib.pyplot as plt

corr = df6m.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11, 9))
sb.heatmap(corr, mask = mask, vmax = .3, center = 0, annot = True,
            square = True, linewidths = .5, cbar_kws={"shrink": .5})

# %%
#les trois valeur noir(proche du zero) Yrsold, MiscVal, 3SsnPorch
